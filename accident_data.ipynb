# %%
import pandas as pd
import numpy as np

data_accident=pd.read_csv("accidents_2005_to_2007.csv")

#converting column count in to a dictionary
dic_col_count=dict(data_accident.count())
dic_col_count
# Out:
# C:\Users\jhcha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# {'Accident_Index': 570011,
#  'Location_Easting_OSGR': 569910,
#  'Location_Northing_OSGR': 569910,
#  'Longitude': 569910,
#  'Latitude': 569910,
#  'Police_Force': 570011,
#  'Accident_Severity': 570011,
#  'Number_of_Vehicles': 570011,
#  'Number_of_Casualties': 570011,
#  'Date': 570011,
#  'Day_of_Week': 570011,
#  'Time': 569944,
#  'Local_Authority_(District)': 570011,
#  'Local_Authority_(Highway)': 570011,
#  '1st_Road_Class': 570011,
#  '1st_Road_Number': 570011,
#  'Road_Type': 570011,
#  'Speed_limit': 570011,
#  'Junction_Detail': 0,
#  'Junction_Control': 333066,
#  '2nd_Road_Class': 570011,
#  '2nd_Road_Number': 570011,
#  'Pedestrian_Crossing-Human_Control': 569994,
#  'Pedestrian_Crossing-Physical_Facilities': 569977,
# ...

# %%
#Getting keys and values separately in to a list
list_values=list(dic_col_count.values())
list_keys=list(dic_col_count.keys())

#Getting mean column count of the columns
mean_count=np.mean(data_accident.count())
to_remove_col=[]
for i in range(len(list_values)):
    if list_values[i]< mean_count:
        to_remove_col.append(list_keys[i])

#Printing columns that have to be removed
print(to_remove_col)
# Out:
# ['Junction_Detail', 'Junction_Control', 'LSOA_of_Accident_Location']

# %%
#Dropping unnecessary columns
data = data_accident.drop(to_remove_col,axis=1)

# %%
#removing null values
data=data.dropna()
data.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  ...  Pedestrian_Crossing-Human_Control  \
# ...

# %%
#converting data frame in to a csv file
data.to_csv("cleaned_data.csv")

# %%
#Comparing originial and cleaned data set
data_accident.shape,data.shape
# Out:
# ((570011, 33), (567149, 30))
